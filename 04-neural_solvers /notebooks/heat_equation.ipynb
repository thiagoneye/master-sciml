# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoneye/master-sciml/blob/main/04-neural_solvers%20/notebooks/heat_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PINN para a Equação do Calor 1D
#
# Este notebook implementa uma **Rede Neural Informada pela Física (PINN)** para resolver a Equação do Calor 1D.
#
# A abordagem combina o aprendizado supervisionado tradicional com a imposição de uma restrição física (a própria equação diferencial parcial), permitindo que a rede neural aprenda a solução do problema em todo o domínio espaço-tempo.
#
# ### A Equação do Calor 1D Transiente
#
# A equação governante do fenômeno é:
#
# $$ \frac{\partial T}{\partial t} = \alpha \frac{\partial^2 T}{\partial x^2} $$
#
# Onde:
# - $T$ é a temperatura.
# - $t$ é o tempo.
# - $x$ é a posição.
# - $\alpha$ é a difusividade térmica do material (uma constante).
#
# A rede neural será treinada para aproximar a função $T(x, t)$. A função de perda total será uma combinação de:
#
# 1.  **Perda de Dados (MSE):** O erro entre a previsão da rede e os dados de medição fornecidos.
# 2.  **Perda da Física (Residual da PDE):** Uma medida de quanto a saída da rede viola a equação do calor.
#
# ### Resumo do Procedimento
#
# 1.  **Carregar e Preparar Dados**: Carregue seu `df` e crie tensores para as posições `(x, t)` e temperaturas `T`.
# 2.  **Gerar Pontos de Colocação**: Crie um conjunto de pontos `(x, t)` aleatórios dentro do seu domínio para avaliar a perda da física.
# 3.  **Definir o Modelo**: Crie uma rede neural sequencial com Keras que mapeia `(x, t)` para `T`.
# 4.  **Implementar as Funções de Perda**:
#     - `data_loss`: MSE entre as previsões e os dados reais.
#     - `physics_loss`: MSE do residual da PDE, calculado usando `tf.GradientTape` para obter as derivadas.
# 5.  **Criar o Loop de Treinamento**:
#     - Em cada época, calcule a perda de dados e a perda da física.
#     - Some-as para obter a perda total.
#     - Use `tf.GradientTape` para encontrar os gradientes da perda total em relação aos pesos do modelo.
#     - Aplique esses gradientes usando um otimizador como o Adam.
# 6.  **Treinar e Avaliar**: Execute o loop por um número suficiente de épocas e, ao final, use o `pinn_model` treinado para fazer previsões e visualizar a solução.

# %% [markdown]
# ### Importações

# %%
import os

# os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp

import time

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

tf.random.set_seed(42)
np.random.seed(42)

print(f"TensorFlow Version: {tf.__version__}")

gpus = tf.config.list_physical_devices("GPU")
print(f"Número de GPUs disponíveis: {len(gpus)}")
if gpus:
    print("A GPU está sendo utilizada pelo TensorFlow.")
    print("Detalhes da GPU:", gpus)
else:
    print("O TensorFlow NÃO encontrou a GPU.")
# Out:
# TensorFlow Version: 2.19.0
# Número de GPUs disponíveis: 1
# A GPU está sendo utilizada pelo TensorFlow.
# Detalhes da GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Leitura e Preparação dos Dados

# %%
# Parâmetros do problema
ALPHA = 0.5

# Leitura dos dados
df_full = pd.read_csv("heat_equation.csv")
df = df_full[
    (df_full["time"] == 0) | (df_full["position"] == 0) | (df_full["position"] == 1)
]
# df = df.sample(frac=0.665, random_state=42)
print(f"Quantidade de pontos de treinamento {len(df)}.")

# Dados completos, entrada (x, t) e saída (T)
X = df_full[["time", "position"]].values
T = df_full[["temperature"]].values

# Dados de treino
X_train_raw = df[["time", "position"]].values
T_train_raw = df[["temperature"]].values

# Converte para tensores do TensorFlow
X_train_tf = tf.convert_to_tensor(X_train_raw, dtype=tf.float32)
T_train_tf = tf.convert_to_tensor(T_train_raw, dtype=tf.float32)

# Plot
fig, ax = plt.subplots(figsize=(8, 3))

ax.scatter(X_train_raw[:, 0], X_train_raw[:, 1])

ax.set_title("Pontos de Treinamento", fontsize=14)
ax.set_xlabel("Tempo (t)", fontsize=10)
ax.set_ylabel("Posição (x)", fontsize=10)
ax.set_xlim([X[:, 0].min(), X[:, 0].max()])
ax.set_ylim([X[:, 1].min(), X[:, 1].max()])
# Out:
# Quantidade de pontos de treinamento 301.
# (0.0, 1.0)

# %% [markdown]
# ### Normalização dos Dados
#
# Os dados das entrada e saída já se encontram normalizado, estando nas faixas `[0, 1]` e `[-1, 1]` respectivamente. Buscando melhorar a estabilidade e a velocidade do treinamento.

# %% [markdown]
# ### Geração dos Pontos de Colocação
#
# Estes são os pontos no interior do domínio onde não conhecemos a temperatura. Eles serão usados para calcular a **perda da física** ($L_{física}$), forçando a rede a obedecer à equação do calor.

# %%
N_collocation = 20000

# Pega os limites do domínio a partir dos dados
t_min, t_max = df_full["time"].min(), df_full["time"].max()
x_min, x_max = df_full["position"].min(), df_full["position"].max()

# Gera pontos aleatórios dentro desses limites
x_collocation = tf.random.uniform(
    (N_collocation, 1), minval=x_min, maxval=x_max, dtype=tf.float32
)
t_collocation = tf.random.uniform(
    (N_collocation, 1), minval=t_min, maxval=t_max, dtype=tf.float32
)
X_collocation_raw = tf.concat([t_collocation, x_collocation], axis=1)
X_collocation_tf = tf.convert_to_tensor(X_collocation_raw, dtype=tf.float32)

# Plot
fig, ax = plt.subplots(figsize=(8, 3))

ax.scatter(X_collocation_raw[:, 0], X_collocation_raw[:, 1])

ax.set_title("Pontos de Colocação", fontsize=14)
ax.set_xlabel("Tempo (t)", fontsize=10)
ax.set_ylabel("Posição (x)", fontsize=10)
ax.set_xlim([t_min, t_max])
ax.set_ylim([x_min, x_max])
# Out:
# (0.0, 1.0)

# %% [markdown]
# ### Construção do Modelo (Rede Neural)

# %%
def create_pinn_model(num_hidden_layers=5, num_neurons=256):
    model = tf.keras.Sequential()

    model.add(tf.keras.layers.InputLayer(input_shape=(2,)))

    for _ in range(num_hidden_layers):
        model.add(tf.keras.layers.Dense(num_neurons, activation="tanh")) # tanh OR swish OR silu
        model.add(tf.keras.layers.Dropout(0.3))

    model.add(tf.keras.layers.Dense(1, activation="linear"))

    return model


pinn_model = create_pinn_model()
pinn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 256)            │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 264,193 (1.01 MB)
#  Trainable params: 264,193 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Função de Perda Híbrida
#
# A função de perda total é a soma da perda nos dados e da perda na física. Aqui, implementamos o cálculo do resíduo da EDP.

# %%
def physics_loss(model, t, x):
    with tf.GradientTape(persistent=True) as tape:
        tape.watch(x)
        tape.watch(t)

        X_concat = tf.concat([t, x], axis=1)
        T_pred = model(X_concat)

        dT_dx = tape.gradient(T_pred, x)
        dT_dt = tape.gradient(T_pred, t)
        d2T_dx2 = tape.gradient(dT_dx, x)

    del tape

    # Resíduo da EDP
    residual = dT_dt - ALPHA * d2T_dx2

    return tf.reduce_mean(tf.square(residual))


def data_loss(model, X_data, T_data):
    T_pred = model(X_data)
    return tf.reduce_mean(tf.square(T_pred - T_data))

# %% [markdown]
# ### Loop de Treinamento Customizado
#
# Usamos um loop customizado para calcular as perdas e aplicar os gradientes a cada época.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

W_DATA = 1.0
W_PHYSICS = 1.0


@tf.function
def train_step(model, X_data, T_data, X_collocation):
    with tf.GradientTape() as tape:
        loss_d = data_loss(model, X_data, T_data)
        loss_p = physics_loss(model, X_collocation[:, 0:1], X_collocation[:, 1:2])
        total_loss = W_DATA * loss_d + W_PHYSICS * loss_p

    gradients = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss_d, loss_p, total_loss


print("Iniciando Fase 1: Treinamento com Adam...")

EPOCHS_ADAM = 100000
start_time = time.time()
break_time = time.time()

for epoch in range(EPOCHS_ADAM):
    loss_d, loss_p, total_loss = train_step(
        pinn_model, X_train_tf, T_train_tf, X_collocation_tf
    )
    if (epoch + 1) % 500 == 0:
        print(
            f"Epoch {epoch+1:5d}, Time: {time.time() - break_time:.2f}s, Loss_Data: {loss_d:.4e}, Loss_Physics: {loss_p:.4e}, Loss_Total: {total_loss:.4e}"
        )
        break_time = time.time()
adam_time = time.time() - start_time

print(f"Fase 1 (Adam) concluída em {adam_time:.2f} segundos.")
print("\nIniciando Fase 2: Refinamento com L-BFGS...")


# Função auxiliar para definir os pesos a partir de um vetor 1D
def set_weights(model, weights_1d):
    """
    Desachata um vetor 1D de pesos e os atribui às variáveis do modelo.
    Esta função corrige a lógica de unflattening.
    """
    shapes = [v.shape for v in model.trainable_variables]
    sizes = [tf.reduce_prod(s) for s in shapes]

    start = 0
    for i, (shape, size) in enumerate(zip(shapes, sizes)):
        end = start + size
        # Pega a fatia do vetor 1D e remodela para a forma original da camada
        w = tf.reshape(weights_1d[start:end], shape)
        model.trainable_variables[i].assign(w)
        start = end


# Função de perda e gradientes que será passada para o otimizador L-BFGS
@tf.function
def loss_and_grads_func(weights_1d):
    """
    Calcula a perda e os gradientes para um dado vetor 1D de pesos.
    """
    # L-BFGS trabalha com float64, mas o modelo usa float32. Fazemos o cast temporário.
    set_weights(pinn_model, tf.cast(weights_1d, dtype=tf.float32))

    # Calcula a perda com os novos pesos
    with tf.GradientTape() as tape:
        loss_d = data_loss(pinn_model, X_train_tf, T_train_tf)
        loss_p = physics_loss(
            pinn_model, X_collocation_tf[:, 0:1], X_collocation_tf[:, 1:2]
        )
        total_loss = loss_d + loss_p

    # Calcula os gradientes (eles serão float32)
    grads = tape.gradient(total_loss, pinn_model.trainable_variables)

    # Achata a lista de gradientes em um único vetor 1D
    grads_1d = tf.concat([tf.reshape(g, [-1]) for g in grads], axis=0)

    # Para estabilidade numérica, retorna a perda e os gradientes como float64
    return tf.cast(total_loss, tf.float64), tf.cast(grads_1d, tf.float64)


# Execução da otimização L-BFGS

# Pega os pesos atuais do modelo (após Adam) e os achata em um vetor 1D
initial_weights = tf.concat(
    [tf.reshape(v, [-1]) for v in pinn_model.trainable_variables], axis=0
)

start_time = time.time()
# Chama o otimizador L-BFGS
# Nota: O L-BFGS não imprime o progresso por padrão. O cálculo da perda é feito dentro da função.
results = tfp.optimizer.lbfgs_minimize(
    value_and_gradients_function=loss_and_grads_func,
    initial_position=tf.cast(
        initial_weights, tf.float64
    ),  # Importante: passar pesos como float64
    num_correction_pairs=100,
    max_iterations=100000,
    tolerance=1e-10,
)
lbfgs_time = time.time() - start_time
print(f"Fase 2 (L-BFGS) concluída em {lbfgs_time:.2f} segundos.")


# Atribuição final dos pesos otimizados
# `results.position` contém o vetor 1D de pesos otimizados (em float64)
optimized_weights_1d = results.position
set_weights(pinn_model, tf.cast(optimized_weights_1d, dtype=tf.float32))

# Imprime a perda final após L-BFGS
final_loss_d = data_loss(pinn_model, X_train_tf, T_train_tf)
final_loss_p = physics_loss(
    pinn_model, X_collocation_tf[:, 0:1], X_collocation_tf[:, 1:2]
)
final_total_loss = final_loss_d + final_loss_p

print("\nTreinamento concluído.")
print(
    f"Perda Final (após L-BFGS): Loss_Data: {final_loss_d:.4e}, Loss_Physics: {final_loss_p:.4e}, Loss_Total: {final_total_loss:.4e}"
)
# Out:
# Iniciando Fase 1: Treinamento com Adam...
# Epoch   500, Time: 7.5 s, Loss_Data: 3.1759e-03, Loss_Physics: 7.5073e-04, Loss_Total: 3.9266e-03
# Epoch  1000, Time: 5.7 s, Loss_Data: 1.6377e-03, Loss_Physics: 2.9157e-04, Loss_Total: 1.9293e-03
# Epoch  1500, Time: 5.7 s, Loss_Data: 1.3899e-03, Loss_Physics: 3.8861e-04, Loss_Total: 1.7785e-03
# Epoch  2000, Time: 5.7 s, Loss_Data: 1.2542e-03, Loss_Physics: 4.9542e-04, Loss_Total: 1.7496e-03
# Epoch  2500, Time: 5.7 s, Loss_Data: 1.0582e-03, Loss_Physics: 1.8589e-04, Loss_Total: 1.2441e-03
# Epoch  3000, Time: 5.7 s, Loss_Data: 9.4990e-04, Loss_Physics: 1.3783e-04, Loss_Total: 1.0877e-03
# Epoch  3500, Time: 5.7 s, Loss_Data: 9.6281e-04, Loss_Physics: 1.1869e-03, Loss_Total: 2.1497e-03
# Epoch  4000, Time: 5.7 s, Loss_Data: 8.0474e-04, Loss_Physics: 1.3071e-04, Loss_Total: 9.3545e-04
# Epoch  4500, Time: 5.7 s, Loss_Data: 7.2568e-04, Loss_Physics: 1.2528e-04, Loss_Total: 8.5096e-04
# Epoch  5000, Time: 5.7 s, Loss_Data: 6.5559e-04, Loss_Physics: 1.0111e-04, Loss_Total: 7.5670e-04
# Epoch  5500, Time: 5.7 s, Loss_Data: 5.8392e-04, Loss_Physics: 9.5110e-05, Loss_Total: 6.7903e-04
# Epoch  6000, Time: 5.7 s, Loss_Data: 5.2112e-04, Loss_Physics: 2.4689e-04, Loss_Total: 7.6801e-04
# Epoch  6500, Time: 5.7 s, Loss_Data: 4.4704e-04, Loss_Physics: 8.5692e-05, Loss_Total: 5.3274e-04
# Epoch  7000, Time: 5.7 s, Loss_Data: 3.8480e-04, Loss_Physics: 6.5432e-05, Loss_Total: 4.5023e-04
# Epoch  7500, Time: 5.7 s, Loss_Data: 3.3671e-04, Loss_Physics: 7.7074e-05, Loss_Total: 4.1379e-04
# Epoch  8000, Time: 5.7 s, Loss_Data: 9.3618e-04, Loss_Physics: 2.1208e-03, Loss_Total: 3.0570e-03
# Epoch  8500, Time: 5.7 s, Loss_Data: 2.7555e-04, Loss_Physics: 1.1122e-04, Loss_Total: 3.8677e-04
# Epoch  9000, Time: 5.7 s, Loss_Data: 2.1430e-04, Loss_Physics: 5.2357e-05, Loss_Total: 2.6666e-04
# Epoch  9500, Time: 5.7 s, Loss_Data: 1.9271e-04, Loss_Physics: 5.4314e-05, Loss_Total: 2.4702e-04
# Epoch 10000, Time: 5.7 s, Loss_Data: 1.7592e-04, Loss_Physics: 5.1216e-05, Loss_Total: 2.2714e-04
# Epoch 10500, Time: 5.7 s, Loss_Data: 1.6801e-04, Loss_Physics: 6.3008e-05, Loss_Total: 2.3102e-04
# Epoch 11000, Time: 5.7 s, Loss_Data: 1.5392e-04, Loss_Physics: 1.0017e-04, Loss_Total: 2.5409e-04
# Epoch 11500, Time: 5.7 s, Loss_Data: 1.4186e-04, Loss_Physics: 5.0700e-05, Loss_Total: 1.9256e-04
# Epoch 12000, Time: 5.7 s, Loss_Data: 1.3408e-04, Loss_Physics: 5.8637e-05, Loss_Total: 1.9271e-04
# Epoch 12500, Time: 5.7 s, Loss_Data: 1.2481e-04, Loss_Physics: 3.8273e-05, Loss_Total: 1.6309e-04
# Epoch 13000, Time: 5.7 s, Loss_Data: 1.3507e-04, Loss_Physics: 1.0692e-04, Loss_Total: 2.4199e-04
# Epoch 13500, Time: 5.7 s, Loss_Data: 1.1825e-04, Loss_Physics: 4.9062e-05, Loss_Total: 1.6731e-04
# Epoch 14000, Time: 5.7 s, Loss_Data: 1.0706e-04, Loss_Physics: 3.3964e-05, Loss_Total: 1.4103e-04
# Epoch 14500, Time: 5.7 s, Loss_Data: 1.0472e-04, Loss_Physics: 4.2790e-05, Loss_Total: 1.4751e-04
# Epoch 15000, Time: 5.7 s, Loss_Data: 1.1211e-04, Loss_Physics: 6.2200e-05, Loss_Total: 1.7432e-04
# Epoch 15500, Time: 5.7 s, Loss_Data: 9.3030e-05, Loss_Physics: 4.7785e-05, Loss_Total: 1.4081e-04
# Epoch 16000, Time: 5.7 s, Loss_Data: 9.2502e-05, Loss_Physics: 3.9469e-05, Loss_Total: 1.3197e-04
# Epoch 16500, Time: 5.7 s, Loss_Data: 1.6648e-03, Loss_Physics: 2.4117e-03, Loss_Total: 4.0765e-03
# Epoch 17000, Time: 5.7 s, Loss_Data: 8.1230e-05, Loss_Physics: 3.0761e-05, Loss_Total: 1.1199e-04
# Epoch 17500, Time: 5.7 s, Loss_Data: 7.7533e-05, Loss_Physics: 3.1343e-05, Loss_Total: 1.0888e-04
# Epoch 18000, Time: 5.7 s, Loss_Data: 7.8286e-05, Loss_Physics: 3.2699e-05, Loss_Total: 1.1098e-04
# Epoch 18500, Time: 5.7 s, Loss_Data: 9.3084e-05, Loss_Physics: 3.2511e-04, Loss_Total: 4.1819e-04
# Epoch 19000, Time: 5.7 s, Loss_Data: 9.6629e-05, Loss_Physics: 4.0889e-04, Loss_Total: 5.0552e-04
# Epoch 19500, Time: 5.7 s, Loss_Data: 6.5627e-05, Loss_Physics: 1.8911e-05, Loss_Total: 8.4538e-05
# Epoch 20000, Time: 5.7 s, Loss_Data: 6.7528e-05, Loss_Physics: 3.1698e-05, Loss_Total: 9.9226e-05
# Epoch 20500, Time: 5.7 s, Loss_Data: 1.0800e-04, Loss_Physics: 3.9661e-05, Loss_Total: 1.4766e-04
# Epoch 21000, Time: 5.7 s, Loss_Data: 7.8334e-05, Loss_Physics: 6.2616e-05, Loss_Total: 1.4095e-04
# Epoch 21500, Time: 5.7 s, Loss_Data: 6.3593e-05, Loss_Physics: 4.4043e-05, Loss_Total: 1.0764e-04
# Epoch 22000, Time: 5.7 s, Loss_Data: 2.7523e-04, Loss_Physics: 1.0657e-03, Loss_Total: 1.3410e-03
# Epoch 22500, Time: 5.7 s, Loss_Data: 5.3593e-05, Loss_Physics: 1.6894e-05, Loss_Total: 7.0487e-05
# Epoch 23000, Time: 5.7 s, Loss_Data: 7.0847e-05, Loss_Physics: 2.7656e-04, Loss_Total: 3.4741e-04
# Epoch 23500, Time: 5.7 s, Loss_Data: 5.2365e-05, Loss_Physics: 2.5921e-05, Loss_Total: 7.8286e-05
# Epoch 24000, Time: 5.7 s, Loss_Data: 5.0428e-05, Loss_Physics: 2.1443e-05, Loss_Total: 7.1871e-05
# Epoch 24500, Time: 5.7 s, Loss_Data: 5.0804e-05, Loss_Physics: 8.2677e-05, Loss_Total: 1.3348e-04
# Epoch 25000, Time: 5.7 s, Loss_Data: 4.5560e-05, Loss_Physics: 2.7010e-05, Loss_Total: 7.2570e-05
# Epoch 25500, Time: 5.7 s, Loss_Data: 4.3593e-05, Loss_Physics: 1.4069e-05, Loss_Total: 5.7662e-05
# Epoch 26000, Time: 5.7 s, Loss_Data: 4.2384e-05, Loss_Physics: 1.3647e-05, Loss_Total: 5.6032e-05
# Epoch 26500, Time: 5.7 s, Loss_Data: 4.0748e-05, Loss_Physics: 1.9366e-05, Loss_Total: 6.0114e-05
# Epoch 27000, Time: 5.7 s, Loss_Data: 3.9927e-05, Loss_Physics: 1.3656e-05, Loss_Total: 5.3583e-05
# Epoch 27500, Time: 5.7 s, Loss_Data: 4.9613e-05, Loss_Physics: 1.5807e-04, Loss_Total: 2.0768e-04
# Epoch 28000, Time: 5.7 s, Loss_Data: 6.7332e-05, Loss_Physics: 6.7888e-05, Loss_Total: 1.3522e-04
# Epoch 28500, Time: 5.7 s, Loss_Data: 5.1807e-05, Loss_Physics: 1.2075e-04, Loss_Total: 1.7256e-04
# Epoch 29000, Time: 5.7 s, Loss_Data: 4.4008e-05, Loss_Physics: 3.8563e-05, Loss_Total: 8.2571e-05
# Epoch 29500, Time: 5.7 s, Loss_Data: 7.1528e-05, Loss_Physics: 9.6730e-05, Loss_Total: 1.6826e-04
# Epoch 30000, Time: 5.7 s, Loss_Data: 4.0326e-05, Loss_Physics: 2.4343e-05, Loss_Total: 6.4669e-05
# Epoch 30500, Time: 5.7 s, Loss_Data: 9.9927e-05, Loss_Physics: 1.4811e-04, Loss_Total: 2.4804e-04
# Epoch 31000, Time: 5.7 s, Loss_Data: 4.4822e-05, Loss_Physics: 4.9093e-05, Loss_Total: 9.3915e-05
# Epoch 31500, Time: 5.7 s, Loss_Data: 3.1316e-05, Loss_Physics: 1.4810e-05, Loss_Total: 4.6126e-05
# Epoch 32000, Time: 5.7 s, Loss_Data: 3.0877e-05, Loss_Physics: 1.1847e-05, Loss_Total: 4.2723e-05
# Epoch 32500, Time: 5.7 s, Loss_Data: 3.2312e-05, Loss_Physics: 3.8531e-05, Loss_Total: 7.0843e-05
# Epoch 33000, Time: 5.7 s, Loss_Data: 2.8951e-05, Loss_Physics: 1.0618e-05, Loss_Total: 3.9569e-05
# Epoch 33500, Time: 5.7 s, Loss_Data: 3.3407e-05, Loss_Physics: 1.9096e-05, Loss_Total: 5.2502e-05
# Epoch 34000, Time: 5.7 s, Loss_Data: 2.8750e-05, Loss_Physics: 2.9020e-05, Loss_Total: 5.7770e-05
# Epoch 34500, Time: 5.7 s, Loss_Data: 3.1519e-05, Loss_Physics: 3.7452e-05, Loss_Total: 6.8972e-05
# Epoch 35000, Time: 5.7 s, Loss_Data: 2.8746e-05, Loss_Physics: 3.7441e-05, Loss_Total: 6.6187e-05
# Epoch 35500, Time: 5.7 s, Loss_Data: 2.7018e-05, Loss_Physics: 1.2121e-05, Loss_Total: 3.9139e-05
# Epoch 36000, Time: 5.7 s, Loss_Data: 2.8229e-05, Loss_Physics: 4.7260e-05, Loss_Total: 7.5489e-05
# Epoch 36500, Time: 5.7 s, Loss_Data: 3.2212e-05, Loss_Physics: 1.2786e-04, Loss_Total: 1.6008e-04
# Epoch 37000, Time: 5.7 s, Loss_Data: 2.4479e-05, Loss_Physics: 9.1909e-06, Loss_Total: 3.3670e-05
# Epoch 37500, Time: 5.7 s, Loss_Data: 2.3268e-05, Loss_Physics: 8.6534e-06, Loss_Total: 3.1921e-05
# Epoch 38000, Time: 5.7 s, Loss_Data: 5.9163e-05, Loss_Physics: 2.3678e-05, Loss_Total: 8.2840e-05
# Epoch 38500, Time: 5.7 s, Loss_Data: 4.1796e-05, Loss_Physics: 2.1276e-04, Loss_Total: 2.5455e-04
# Epoch 39000, Time: 5.7 s, Loss_Data: 2.5534e-05, Loss_Physics: 8.9351e-06, Loss_Total: 3.4469e-05
# Epoch 39500, Time: 5.7 s, Loss_Data: 2.3779e-05, Loss_Physics: 1.3522e-05, Loss_Total: 3.7300e-05
# Epoch 40000, Time: 5.7 s, Loss_Data: 2.0653e-05, Loss_Physics: 7.8061e-06, Loss_Total: 2.8459e-05
# Epoch 40500, Time: 5.7 s, Loss_Data: 2.1992e-05, Loss_Physics: 1.8342e-05, Loss_Total: 4.0334e-05
# Epoch 41000, Time: 5.7 s, Loss_Data: 2.0858e-05, Loss_Physics: 2.6996e-05, Loss_Total: 4.7855e-05
# Epoch 41500, Time: 5.7 s, Loss_Data: 2.6939e-05, Loss_Physics: 1.0819e-04, Loss_Total: 1.3512e-04
# Epoch 42000, Time: 5.7 s, Loss_Data: 2.4085e-05, Loss_Physics: 1.1273e-04, Loss_Total: 1.3681e-04
# Epoch 42500, Time: 5.7 s, Loss_Data: 1.8853e-05, Loss_Physics: 7.1775e-06, Loss_Total: 2.6030e-05
# Epoch 43000, Time: 5.7 s, Loss_Data: 2.9659e-05, Loss_Physics: 2.8440e-05, Loss_Total: 5.8100e-05
# Epoch 43500, Time: 5.7 s, Loss_Data: 2.8614e-05, Loss_Physics: 3.8480e-05, Loss_Total: 6.7093e-05
# Epoch 44000, Time: 5.7 s, Loss_Data: 1.9577e-05, Loss_Physics: 8.4177e-05, Loss_Total: 1.0375e-04
# Epoch 44500, Time: 5.7 s, Loss_Data: 1.8530e-05, Loss_Physics: 1.8269e-05, Loss_Total: 3.6800e-05
# Epoch 45000, Time: 5.7 s, Loss_Data: 1.7502e-05, Loss_Physics: 1.9619e-05, Loss_Total: 3.7121e-05
# Epoch 45500, Time: 5.7 s, Loss_Data: 1.6583e-05, Loss_Physics: 7.7590e-06, Loss_Total: 2.4342e-05
# Epoch 46000, Time: 5.7 s, Loss_Data: 1.8480e-05, Loss_Physics: 2.3586e-05, Loss_Total: 4.2066e-05
# Epoch 46500, Time: 5.7 s, Loss_Data: 1.7281e-05, Loss_Physics: 3.5342e-05, Loss_Total: 5.2623e-05
# Epoch 47000, Time: 5.7 s, Loss_Data: 2.3066e-05, Loss_Physics: 2.1000e-04, Loss_Total: 2.3306e-04
# Epoch 47500, Time: 5.7 s, Loss_Data: 1.5254e-05, Loss_Physics: 8.9112e-06, Loss_Total: 2.4165e-05
# Epoch 48000, Time: 5.7 s, Loss_Data: 1.5943e-05, Loss_Physics: 2.3454e-05, Loss_Total: 3.9397e-05
# Epoch 48500, Time: 5.7 s, Loss_Data: 1.7312e-05, Loss_Physics: 2.0956e-05, Loss_Total: 3.8268e-05
# Epoch 49000, Time: 5.7 s, Loss_Data: 3.5148e-05, Loss_Physics: 1.8226e-05, Loss_Total: 5.3374e-05
# Epoch 49500, Time: 5.7 s, Loss_Data: 1.4211e-05, Loss_Physics: 5.8252e-06, Loss_Total: 2.0036e-05
# Epoch 50000, Time: 5.7 s, Loss_Data: 4.7738e-05, Loss_Physics: 4.3577e-04, Loss_Total: 4.8351e-04
# Epoch 50500, Time: 5.7 s, Loss_Data: 5.2680e-05, Loss_Physics: 7.2407e-05, Loss_Total: 1.2509e-04
# Epoch 51000, Time: 5.7 s, Loss_Data: 2.2725e-05, Loss_Physics: 3.4116e-05, Loss_Total: 5.6841e-05
# Epoch 51500, Time: 5.7 s, Loss_Data: 1.3647e-05, Loss_Physics: 5.1872e-06, Loss_Total: 1.8834e-05
# Epoch 52000, Time: 5.7 s, Loss_Data: 1.3819e-05, Loss_Physics: 1.2785e-05, Loss_Total: 2.6604e-05
# Epoch 52500, Time: 5.7 s, Loss_Data: 1.4489e-05, Loss_Physics: 2.0110e-05, Loss_Total: 3.4599e-05
# Epoch 53000, Time: 5.7 s, Loss_Data: 1.2828e-05, Loss_Physics: 8.4694e-06, Loss_Total: 2.1297e-05
# Epoch 53500, Time: 5.7 s, Loss_Data: 1.4019e-05, Loss_Physics: 1.2018e-05, Loss_Total: 2.6037e-05
# Epoch 54000, Time: 5.7 s, Loss_Data: 4.4328e-05, Loss_Physics: 3.1050e-05, Loss_Total: 7.5378e-05
# Epoch 54500, Time: 5.7 s, Loss_Data: 2.2443e-05, Loss_Physics: 2.9149e-05, Loss_Total: 5.1592e-05
# Epoch 55000, Time: 5.7 s, Loss_Data: 1.1147e-05, Loss_Physics: 4.5388e-06, Loss_Total: 1.5686e-05
# Epoch 55500, Time: 5.7 s, Loss_Data: 1.2142e-05, Loss_Physics: 1.4742e-05, Loss_Total: 2.6883e-05
# Epoch 56000, Time: 5.7 s, Loss_Data: 1.4313e-05, Loss_Physics: 1.1983e-05, Loss_Total: 2.6297e-05
# Epoch 56500, Time: 5.7 s, Loss_Data: 2.0252e-05, Loss_Physics: 1.2621e-04, Loss_Total: 1.4646e-04
# Epoch 57000, Time: 5.7 s, Loss_Data: 1.7050e-05, Loss_Physics: 2.3247e-05, Loss_Total: 4.0297e-05
# Epoch 57500, Time: 5.7 s, Loss_Data: 1.1516e-05, Loss_Physics: 1.2185e-05, Loss_Total: 2.3701e-05
# Epoch 58000, Time: 5.7 s, Loss_Data: 1.0242e-05, Loss_Physics: 5.7645e-06, Loss_Total: 1.6007e-05
# Epoch 58500, Time: 5.7 s, Loss_Data: 1.0556e-05, Loss_Physics: 7.8130e-06, Loss_Total: 1.8369e-05
# Epoch 59000, Time: 5.7 s, Loss_Data: 1.1240e-05, Loss_Physics: 5.7926e-06, Loss_Total: 1.7033e-05
# Epoch 59500, Time: 5.7 s, Loss_Data: 1.3192e-05, Loss_Physics: 6.2488e-05, Loss_Total: 7.5680e-05
# Epoch 60000, Time: 5.7 s, Loss_Data: 1.8753e-05, Loss_Physics: 1.0966e-05, Loss_Total: 2.9719e-05
# Epoch 60500, Time: 5.7 s, Loss_Data: 1.7329e-05, Loss_Physics: 4.0150e-05, Loss_Total: 5.7480e-05
# Epoch 61000, Time: 5.7 s, Loss_Data: 2.0872e-05, Loss_Physics: 1.2493e-05, Loss_Total: 3.3364e-05
# Epoch 61500, Time: 5.7 s, Loss_Data: 1.2832e-05, Loss_Physics: 9.1496e-06, Loss_Total: 2.1982e-05
# Epoch 62000, Time: 5.7 s, Loss_Data: 1.7617e-05, Loss_Physics: 1.2881e-05, Loss_Total: 3.0498e-05
# Epoch 62500, Time: 5.7 s, Loss_Data: 9.5022e-06, Loss_Physics: 1.4470e-05, Loss_Total: 2.3972e-05
# Epoch 63000, Time: 5.7 s, Loss_Data: 9.4198e-06, Loss_Physics: 2.3949e-05, Loss_Total: 3.3369e-05
# Epoch 63500, Time: 5.7 s, Loss_Data: 1.0781e-05, Loss_Physics: 3.1883e-05, Loss_Total: 4.2664e-05
# Epoch 64000, Time: 5.7 s, Loss_Data: 9.4647e-06, Loss_Physics: 5.1980e-05, Loss_Total: 6.1445e-05
# Epoch 64500, Time: 5.7 s, Loss_Data: 1.6314e-05, Loss_Physics: 4.3221e-05, Loss_Total: 5.9536e-05
# Epoch 65000, Time: 5.7 s, Loss_Data: 9.1959e-06, Loss_Physics: 1.7720e-05, Loss_Total: 2.6916e-05
# Epoch 65500, Time: 5.7 s, Loss_Data: 1.2555e-05, Loss_Physics: 6.6994e-05, Loss_Total: 7.9548e-05
# Epoch 66000, Time: 5.7 s, Loss_Data: 8.7539e-06, Loss_Physics: 2.2162e-05, Loss_Total: 3.0916e-05
# Epoch 66500, Time: 5.7 s, Loss_Data: 5.7128e-05, Loss_Physics: 2.2054e-04, Loss_Total: 2.7767e-04
# Epoch 67000, Time: 5.7 s, Loss_Data: 2.9776e-05, Loss_Physics: 6.6714e-05, Loss_Total: 9.6490e-05
# Epoch 67500, Time: 5.7 s, Loss_Data: 1.8159e-05, Loss_Physics: 9.0638e-05, Loss_Total: 1.0880e-04
# Epoch 68000, Time: 5.7 s, Loss_Data: 8.0726e-06, Loss_Physics: 1.0630e-05, Loss_Total: 1.8703e-05
# Epoch 68500, Time: 5.7 s, Loss_Data: 2.0063e-05, Loss_Physics: 4.9120e-05, Loss_Total: 6.9183e-05
# Epoch 69000, Time: 5.7 s, Loss_Data: 7.7231e-06, Loss_Physics: 5.6276e-06, Loss_Total: 1.3351e-05
# Epoch 69500, Time: 5.7 s, Loss_Data: 7.0603e-06, Loss_Physics: 4.4602e-06, Loss_Total: 1.1521e-05
# Epoch 70000, Time: 5.7 s, Loss_Data: 8.3238e-06, Loss_Physics: 2.7436e-05, Loss_Total: 3.5759e-05
# Epoch 70500, Time: 5.7 s, Loss_Data: 7.2248e-06, Loss_Physics: 4.9017e-06, Loss_Total: 1.2126e-05
# Epoch 71000, Time: 5.7 s, Loss_Data: 6.9775e-06, Loss_Physics: 3.1133e-06, Loss_Total: 1.0091e-05
# Epoch 71500, Time: 5.7 s, Loss_Data: 9.5441e-06, Loss_Physics: 8.9746e-06, Loss_Total: 1.8519e-05
# Epoch 72000, Time: 5.7 s, Loss_Data: 2.2996e-05, Loss_Physics: 1.1567e-04, Loss_Total: 1.3867e-04
# Epoch 72500, Time: 5.7 s, Loss_Data: 7.7939e-06, Loss_Physics: 1.8682e-05, Loss_Total: 2.6476e-05
# Epoch 73000, Time: 5.7 s, Loss_Data: 3.1440e-05, Loss_Physics: 1.5424e-04, Loss_Total: 1.8568e-04
# Epoch 73500, Time: 5.7 s, Loss_Data: 8.2845e-06, Loss_Physics: 8.3228e-06, Loss_Total: 1.6607e-05
# Epoch 74000, Time: 5.7 s, Loss_Data: 6.7591e-06, Loss_Physics: 3.3941e-06, Loss_Total: 1.0153e-05
# Epoch 74500, Time: 5.7 s, Loss_Data: 1.1008e-05, Loss_Physics: 2.3287e-05, Loss_Total: 3.4296e-05
# Epoch 75000, Time: 5.7 s, Loss_Data: 1.2723e-05, Loss_Physics: 8.5807e-05, Loss_Total: 9.8530e-05
# Epoch 75500, Time: 5.7 s, Loss_Data: 6.8500e-06, Loss_Physics: 5.0246e-06, Loss_Total: 1.1875e-05
# Epoch 76000, Time: 5.7 s, Loss_Data: 3.3528e-05, Loss_Physics: 2.6086e-05, Loss_Total: 5.9613e-05
# Epoch 76500, Time: 5.7 s, Loss_Data: 6.1981e-06, Loss_Physics: 7.3221e-06, Loss_Total: 1.3520e-05
# Epoch 77000, Time: 5.7 s, Loss_Data: 5.8063e-06, Loss_Physics: 2.4554e-06, Loss_Total: 8.2617e-06
# Epoch 77500, Time: 5.7 s, Loss_Data: 6.5474e-06, Loss_Physics: 9.5422e-06, Loss_Total: 1.6090e-05
# Epoch 78000, Time: 5.7 s, Loss_Data: 6.3225e-06, Loss_Physics: 4.8172e-06, Loss_Total: 1.1140e-05
# Epoch 78500, Time: 5.7 s, Loss_Data: 7.8069e-06, Loss_Physics: 2.0461e-05, Loss_Total: 2.8268e-05
# Epoch 79000, Time: 5.7 s, Loss_Data: 8.4476e-06, Loss_Physics: 1.0015e-05, Loss_Total: 1.8463e-05
# Epoch 79500, Time: 5.7 s, Loss_Data: 2.0700e-05, Loss_Physics: 8.6034e-06, Loss_Total: 2.9303e-05
# Epoch 80000, Time: 5.7 s, Loss_Data: 6.1179e-06, Loss_Physics: 7.7929e-06, Loss_Total: 1.3911e-05
# Epoch 80500, Time: 5.7 s, Loss_Data: 5.8816e-06, Loss_Physics: 5.1470e-06, Loss_Total: 1.1029e-05
# Epoch 81000, Time: 5.7 s, Loss_Data: 6.8297e-06, Loss_Physics: 2.7148e-05, Loss_Total: 3.3977e-05
# Epoch 81500, Time: 5.7 s, Loss_Data: 7.3536e-06, Loss_Physics: 1.1722e-05, Loss_Total: 1.9075e-05
# Epoch 82000, Time: 5.7 s, Loss_Data: 6.6121e-06, Loss_Physics: 5.4617e-06, Loss_Total: 1.2074e-05
# Epoch 82500, Time: 5.7 s, Loss_Data: 5.3907e-06, Loss_Physics: 5.0907e-06, Loss_Total: 1.0481e-05
# Epoch 83000, Time: 5.7 s, Loss_Data: 2.4972e-05, Loss_Physics: 1.4031e-04, Loss_Total: 1.6528e-04
# Epoch 83500, Time: 5.7 s, Loss_Data: 5.1444e-06, Loss_Physics: 2.4536e-06, Loss_Total: 7.5979e-06
# Epoch 84000, Time: 5.7 s, Loss_Data: 8.4484e-06, Loss_Physics: 1.6730e-05, Loss_Total: 2.5178e-05
# Epoch 84500, Time: 5.7 s, Loss_Data: 7.3116e-06, Loss_Physics: 2.1255e-05, Loss_Total: 2.8567e-05
# Epoch 85000, Time: 5.7 s, Loss_Data: 1.0856e-05, Loss_Physics: 2.1872e-05, Loss_Total: 3.2728e-05
# Epoch 85500, Time: 5.7 s, Loss_Data: 5.5509e-06, Loss_Physics: 5.1368e-06, Loss_Total: 1.0688e-05
# Epoch 86000, Time: 5.7 s, Loss_Data: 3.7195e-05, Loss_Physics: 5.3519e-05, Loss_Total: 9.0714e-05
# Epoch 86500, Time: 5.7 s, Loss_Data: 2.6069e-05, Loss_Physics: 1.0291e-04, Loss_Total: 1.2898e-04
# Epoch 87000, Time: 5.7 s, Loss_Data: 1.0198e-05, Loss_Physics: 4.7197e-06, Loss_Total: 1.4917e-05
# Epoch 87500, Time: 5.7 s, Loss_Data: 5.3665e-06, Loss_Physics: 3.7323e-06, Loss_Total: 9.0988e-06
# Epoch 88000, Time: 5.7 s, Loss_Data: 5.3505e-05, Loss_Physics: 2.6033e-04, Loss_Total: 3.1384e-04
# Epoch 88500, Time: 5.7 s, Loss_Data: 2.4793e-05, Loss_Physics: 7.2559e-05, Loss_Total: 9.7351e-05
# Epoch 89000, Time: 5.7 s, Loss_Data: 4.6885e-06, Loss_Physics: 3.2640e-06, Loss_Total: 7.9525e-06
# Epoch 89500, Time: 5.7 s, Loss_Data: 3.9966e-05, Loss_Physics: 1.0828e-04, Loss_Total: 1.4825e-04
# Epoch 90000, Time: 5.7 s, Loss_Data: 1.6489e-05, Loss_Physics: 1.2199e-05, Loss_Total: 2.8688e-05
# Epoch 90500, Time: 5.7 s, Loss_Data: 4.5753e-06, Loss_Physics: 5.5280e-06, Loss_Total: 1.0103e-05
# Epoch 91000, Time: 5.7 s, Loss_Data: 2.2008e-05, Loss_Physics: 4.2071e-05, Loss_Total: 6.4078e-05
# Epoch 91500, Time: 5.7 s, Loss_Data: 4.7413e-06, Loss_Physics: 6.6915e-06, Loss_Total: 1.1433e-05
# Epoch 92000, Time: 5.7 s, Loss_Data: 6.9958e-06, Loss_Physics: 5.5486e-05, Loss_Total: 6.2482e-05
# Epoch 92500, Time: 5.7 s, Loss_Data: 6.3665e-06, Loss_Physics: 3.5651e-05, Loss_Total: 4.2017e-05
# Epoch 93000, Time: 5.7 s, Loss_Data: 1.9440e-05, Loss_Physics: 3.3166e-04, Loss_Total: 3.5110e-04
# Epoch 93500, Time: 5.7 s, Loss_Data: 4.8193e-06, Loss_Physics: 3.5888e-06, Loss_Total: 8.4082e-06
# Epoch 94000, Time: 5.7 s, Loss_Data: 7.8838e-06, Loss_Physics: 1.4208e-05, Loss_Total: 2.2092e-05
# Epoch 94500, Time: 5.7 s, Loss_Data: 4.7620e-05, Loss_Physics: 1.4365e-05, Loss_Total: 6.1984e-05
# Epoch 95000, Time: 5.7 s, Loss_Data: 1.2082e-05, Loss_Physics: 2.9460e-05, Loss_Total: 4.1542e-05
# Epoch 95500, Time: 5.7 s, Loss_Data: 1.0743e-05, Loss_Physics: 2.6681e-05, Loss_Total: 3.7424e-05
# Epoch 96000, Time: 5.7 s, Loss_Data: 4.1750e-06, Loss_Physics: 5.2076e-06, Loss_Total: 9.3826e-06
# Epoch 96500, Time: 5.7 s, Loss_Data: 4.3965e-06, Loss_Physics: 1.1566e-05, Loss_Total: 1.5963e-05
# Epoch 97000, Time: 5.7 s, Loss_Data: 1.0717e-05, Loss_Physics: 2.3504e-06, Loss_Total: 1.3067e-05
# Epoch 97500, Time: 5.7 s, Loss_Data: 8.4916e-06, Loss_Physics: 3.4861e-05, Loss_Total: 4.3352e-05
# Epoch 98000, Time: 5.7 s, Loss_Data: 8.0850e-05, Loss_Physics: 8.9756e-05, Loss_Total: 1.7061e-04
# Epoch 98500, Time: 5.7 s, Loss_Data: 5.3403e-06, Loss_Physics: 7.9257e-06, Loss_Total: 1.3266e-05
# Epoch 99000, Time: 5.7 s, Loss_Data: 9.4102e-06, Loss_Physics: 2.6217e-06, Loss_Total: 1.2032e-05
# Epoch 99500, Time: 5.7 s, Loss_Data: 6.2186e-06, Loss_Physics: 5.5934e-06, Loss_Total: 1.1812e-05
# Epoch 100000, Time: 5.7 s, Loss_Data: 4.0720e-06, Loss_Physics: 9.6077e-06, Loss_Total: 1.3680e-05
# Fase 1 (Adam) concluída em 1148.27 segundos.
#
# Iniciando Fase 2: Refinamento com L-BFGS...
# Fase 2 (L-BFGS) concluída em 8.76 segundos.
#
# Treinamento concluído.
# Perda Final (após L-BFGS): Loss_Data: 3.9260e-06, Loss_Physics: 1.3165e-06, Loss_Total: 5.2425e-06

# %% [markdown]
# ### Métricas de Avaliação
#
# Agora, usamos o modelo treinado para prever a temperatura em todo o domínio e comparamos com os dados de treinamento originais.

# %%
# Fazer previsões nos mesmos pontos do DataFrame de treinamento
T_pred = pinn_model.predict(X)

# Calcular as métricas de erro
mse = mean_squared_error(T, T_pred)
mae = mean_absolute_error(T, T_pred)
r2 = r2_score(T, T_pred)

print(f"Erro Quadrático Médio (MSE): {mse:.6f}")
print(f"Erro Absoluto Médio (MAE):  {mae:.6f}")
print(f"R2 Score:  {r2:.6f}")
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Erro Quadrático Médio (MSE): 0.028931
# Erro Absoluto Médio (MAE):  0.134408
# R2 Score:  0.456164

# %% [markdown]
# ### Visualização dos Resultados

# %%
# Perfis de Temperatura ao Longo do Tempo

t = np.unique(X[:, 0])
x = np.unique(X[:, 1])

Nt = len(t)
Nx = len(x)

U_sol = T.reshape([Nt, Nx])
U_pred = T_pred.reshape([Nt, Nx])
Err = U_sol - U_pred

fig, ax = plt.subplots(figsize=(8, 3))

idx_time = [0, Nt // 4, Nt // 2, 3 * Nt // 4, Nt - 1]  # Pega 5 instantes de tempo
for i, t_idx in enumerate(idx_time):
    line = ax.plot(x, U_sol[t_idx, :], label=f"t = {t[t_idx]:.2f} s (true)")[0]
    plot_color = line.get_color()
    ax.plot(x, U_pred[t_idx, :], "x", color=plot_color, label=f"t = {t[t_idx]:.2f} s (pred)")

ax.set_title("Evolução do Perfil de Temperatura", fontsize=14)
ax.set_xlabel("Posição (x)", fontsize=10)
ax.set_ylabel("Temperatura (U)", fontsize=10)
ax.legend()

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# %%
# Mapa de Calor U(x, t) - Valores Reais

fig, ax = plt.subplots(1,3, figsize=(25, 3))

# Meshgrid para as coordenadas. Note que pcolormesh usa as coordenadas dos cantos.
T_grid, X_grid = np.meshgrid(t, x)

# A matriz de cores (U_sol.T) deve ter dimensões (Nx, Nt)
# Usamos shading='gouraud' para interpolação suave de cores.
im = ax[0].pcolormesh(T_grid, X_grid, U_sol.T, cmap="coolwarm", shading="gouraud")

# Adiciona a barra de cores
cbar = fig.colorbar(im, ax=ax[0])
cbar.set_label("Temperatura (U)", fontsize=10)

ax[0].set_title("Solução U(x, t)")
ax[0].set_xlabel("Tempo (t)", fontsize=10)
ax[0].set_ylabel("Posição (x)", fontsize=10)

ax[0].spines["top"].set_visible(False)
ax[0].spines["right"].set_visible(False)

# Mapa de Calor U(x, t) - Valores Previstos

# fig, ax = plt.subplots(figsize=(8, 3))
im = ax[1].pcolormesh(T_grid, X_grid, U_pred.T, cmap="coolwarm", shading="gouraud")
cbar = fig.colorbar(im, ax=ax[1])
cbar.set_label("Temperatura (U)", fontsize=10)

ax[1].set_title("Predição U(x, t)")
ax[1].set_xlabel("Tempo (t)", fontsize=10)
ax[1].set_ylabel("Posição (x)", fontsize=10)

ax[1].spines["top"].set_visible(False)
ax[1].spines["right"].set_visible(False)

# Mapa de Calor do Erro Err(x, t)

# fig, ax = plt.subplots(figsize=(8, 3))
im = ax[2].pcolormesh(T_grid, X_grid, Err.T, cmap="hot", shading="gouraud")
cbar = fig.colorbar(im, ax=ax[2])
cbar.set_label("Erro", fontsize=10)

ax[2].set_title("Erro de Predição")
ax[2].set_xlabel("Tempo (t)", fontsize=10)
ax[2].set_ylabel("Posição (x)", fontsize=10)

ax[2].spines["top"].set_visible(False)
ax[2].spines["right"].set_visible(False)
